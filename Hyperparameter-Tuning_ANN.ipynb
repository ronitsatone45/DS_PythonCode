# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.data (1).csv", delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -7.748432e-17  3.614007e-18 -1.327244e-17  7.762888e-17 -5.493291e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.972738e-15  1.924387e-15  2.192980e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
    model.add(Dense(8, init='uniform', activation='relu'))
    model.add(Dense(1, init='uniform', activation='sigmoid'))
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/5; 1/9] END .......batch_size=10, epochs=10;, score=nan total time=   1.0s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END .......batch_size=10, epochs=10;, score=nan total time=   0.0s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END .......batch_size=10, epochs=10;, score=nan total time=   0.0s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END .......batch_size=10, epochs=10;, score=nan total time=   0.0s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END .......batch_size=10, epochs=10;, score=nan total time=   0.0s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END .......batch_size=10, epochs=50;, score=nan total time=   0.0s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END .......batch_size=10, epochs=50;, score=nan total time=   0.0s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END .......batch_size=10, epochs=50;, score=nan total time=   0.0s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END .......batch_size=10, epochs=50;, score=nan total time=   0.0s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END .......batch_size=10, epochs=50;, score=nan total time=   0.0s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END ......batch_size=10, epochs=100;, score=nan total time=   0.0s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END ......batch_size=10, epochs=100;, score=nan total time=   0.0s
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END ......batch_size=10, epochs=100;, score=nan total time=   0.0s
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END ......batch_size=10, epochs=100;, score=nan total time=   0.0s
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END ......batch_size=10, epochs=100;, score=nan total time=   0.0s
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END .......batch_size=20, epochs=10;, score=nan total time=   0.0s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END .......batch_size=20, epochs=10;, score=nan total time=   0.0s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END .......batch_size=20, epochs=10;, score=nan total time=   0.0s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END .......batch_size=20, epochs=10;, score=nan total time=   0.0s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END .......batch_size=20, epochs=10;, score=nan total time=   0.0s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
# ...
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/5; 5/9] END .......batch_size=20, epochs=50;, score=nan total time=   0.0s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END .......batch_size=20, epochs=50;, score=nan total time=   0.0s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END .......batch_size=20, epochs=50;, score=nan total time=   0.0s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END .......batch_size=20, epochs=50;, score=nan total time=   0.0s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END .......batch_size=20, epochs=50;, score=nan total time=   0.0s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END ......batch_size=20, epochs=100;, score=nan total time=   0.0s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END ......batch_size=20, epochs=100;, score=nan total time=   0.0s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END ......batch_size=20, epochs=100;, score=nan total time=   0.0s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END ......batch_size=20, epochs=100;, score=nan total time=   0.0s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END ......batch_size=20, epochs=100;, score=nan total time=   0.0s
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 1/5; 7/9] END .......batch_size=40, epochs=10;, score=nan total time=   0.0s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 2/5; 7/9] END .......batch_size=40, epochs=10;, score=nan total time=   0.0s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 3/5; 7/9] END .......batch_size=40, epochs=10;, score=nan total time=   0.0s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 4/5; 7/9] END .......batch_size=40, epochs=10;, score=nan total time=   0.0s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 5/5; 7/9] END .......batch_size=40, epochs=10;, score=nan total time=   0.0s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 1/5; 8/9] END .......batch_size=40, epochs=50;, score=nan total time=   0.0s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 2/5; 8/9] END .......batch_size=40, epochs=50;, score=nan total time=   0.0s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END .......batch_size=40, epochs=50;, score=nan total time=   0.0s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 4/5; 8/9] END .......batch_size=40, epochs=50;, score=nan total time=   0.0s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END .......batch_size=40, epochs=50;, score=nan total time=   0.0s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 1/5; 9/9] END ......batch_size=40, epochs=100;, score=nan total time=   0.0s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 219, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 153, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-8-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\layers\core.py", line 1147, in __init__
#     super(Dense, self).__init__(
#   File "C:\Users\Hp\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py", line 530, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 323, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "C:\Users\Hp\anaconda3\lib\site-packages\keras\utils\generic_utils.py", line 1143, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# [CV 2/5; 9/9] END ......batch_size=40, epochs=100;, score=nan total time=   0.0s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 3/5; 9/9] END ......batch_size=40, epochs=100;, score=nan total time=   0.0s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 4/5; 9/9] END ......batch_size=40, epochs=100;, score=nan total time=   0.0s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 5/5; 9/9] END ......batch_size=40, epochs=100;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0efede6617b0> in <module>
#       8 # Build and fit the GridSearchCV
#       9 grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
# ---> 10 grid_result = grid.fit(X_standardized,y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     217       raise ValueError('Invalid shape for y: ' + str(y.shape))
#     218     self.n_classes_ = len(self.classes_)
# --> 219     return super(KerasClassifier, self).fit(x, y, **kwargs)
#     220
#     221   def predict(self, x, **kwargs):
#
# ~\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     151           **self.filter_sk_params(self.build_fn.__call__))
#     152     else:
# --> 153       self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#     154
#     155     if (losses.is_categorical_crossentropy(self.model.loss) and
#
# <ipython-input-8-aee56e00d4c0> in create_model()
#       2 def create_model():
#       3     model = Sequential()
# ----> 4     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#       5     model.add(Dense(8, init='uniform', activation='relu'))
#       6     model.add(Dense(1, init='uniform', activation='sigmoid'))
#
# ~\anaconda3\lib\site-packages\keras\layers\core.py in __init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#    1145                bias_constraint=None,
#    1146                **kwargs):
# -> 1147     super(Dense, self).__init__(
#    1148         activity_regularizer=activity_regularizer, **kwargs)
#    1149
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\lib\site-packages\keras\engine\base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     321     }
#     322     # Validate optional keyword arguments.
# --> 323     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     324
#     325     # Mutable properties
#
# ~\anaconda3\lib\site-packages\keras\utils\generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    1141   for kwarg in kwargs:
#    1142     if kwarg not in allowed_kwargs:
# -> 1143       raise TypeError(error_message, kwarg)
#    1144
#    1145
#
# TypeError: ('Keyword argument not understood:', 'init')

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.760 total time=   6.7s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.714 total time=   1.5s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.760 total time=   1.5s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.745 total time=   1.6s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.693 total time=   1.5s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.753 total time=   2.1s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.727 total time=   1.3s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.734 total time=   1.1s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.837 total time=   1.1s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.771 total time=   1.1s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.740 total time=   1.1s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.649 total time=   1.2s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.773 total time=   1.1s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.843 total time=   1.2s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.771 total time=   1.1s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.773 total time=   1.2s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.675 total time=   1.5s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.701 total time=   1.2s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.830 total time=   1.2s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.647 total time=   1.2s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.747 total time=   1.2s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.714 total time=   1.4s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.760 total time=   1.3s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.843 total time=   1.8s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.758 total time=   1.7s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.721 total time=   1.6s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.701 total time=   2.0s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.773 total time=   2.2s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.810 total time=   1.5s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.758 total time=   1.3s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.740 total time=   1.2s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.688 total time=   1.2s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.753 total time=   1.2s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.804 total time=   1.1s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.752 total time=   1.3s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.747 total time=   1.2s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.734 total time=   1.2s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.747 total time=   1.2s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.830 total time=   1.7s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.752 total time=   1.3s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.721 total time=   1.3s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.675 total time=   1.2s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.760 total time=   1.2s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.732 total time=   1.4s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.712 total time=   1.3s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7644257783889771, using {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7343349456787109,0.026581777191207488 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7644257783889771,0.03924561671084023 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7553433537483215,0.06280876036019935 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7252949714660645,0.06696327291884693 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.764417290687561,0.04262142433431348 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7526865363121032,0.03854340245841445 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.747474753856659,0.03684883351354371 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7617944359779358,0.03464738547125577 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7200577259063721,0.027487711756570915 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform;, score=0.649 total time=   1.5s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform;, score=0.584 total time=   1.2s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform;, score=0.630 total time=   1.3s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform;, score=0.745 total time=   1.9s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform;, score=0.647 total time=   1.3s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5;
 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7644342541694641,0.046099197463484995 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7566165924072266,0.0437257569411756 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7579067945480347,0.040933605217224146 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7657074928283691,0.0441636931013981 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.760 total time=   1.3s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.682 total time=   1.4s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.708 total time=   1.3s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.810 total time=   1.2s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.745 total time=   1.2s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.760 total time=   1.4s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.682 total time=   1.4s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.734 total time=   1.3s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.784 total time=   1.8s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.752 total time=   1.4s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.760 total time=   1.9s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.682 total time=   1.5s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.753 total time=   1.6s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.817 total time=   1.3s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.765 total time=   1.4s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.753 total time=   1.3s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.701 total time=   1.4s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.753 total time=   2.0s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.784 total time=   2.4s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.765 total time=   1.8s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.766 total time=   1.2s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.688 total time=   1.3s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.766 total time=   1.3s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.817 total time=   1.2s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.784 total time=   1.3s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.753 total time=   1.2s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.701 total time=   1.2s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.760 total time=   1.2s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.843 total time=   1.3s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.771 total time=   1.2s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.773 total time=   1.6s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.708 total time=   1.2s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.760 total time=   1.2s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.824 total time=   1.3s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.752 total time=   1.2s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.766 total time=   1.2s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.721 total time=   1.3s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.740 total time=   1.2s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.817 total time=   1.2s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.765 total time=   1.2s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.760 total time=   1.3s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.714 total time=   1.6s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.753 total time=   1.2s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.837 total time=   1.2s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.752 total time=   1.2s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7657329559326171, using {'neuron1': 8, 'neuron2': 8}
# 0.7409812450408936,0.04426642121028979 with: {'neuron1': 4, 'neuron2': 2}
# 0.7422544836997986,0.034314147557417615 with: {'neuron1': 4, 'neuron2': 4}
# 0.7553009033203125,0.04316958224239693 with: {'neuron1': 4, 'neuron2': 8}
# 0.7513623595237732,0.02748568223765195 with: {'neuron1': 8, 'neuron2': 2}
# 0.7644172787666321,0.04232914908033029 with: {'neuron1': 8, 'neuron2': 4}
# 0.7657329559326171,0.045531011543316666 with: {'neuron1': 8, 'neuron2': 8}
# 0.7630846261978149,0.03727225578979093 with: {'neuron1': 16, 'neuron2': 2}
# 0.7617944240570068,0.03231441233495355 with: {'neuron1': 16, 'neuron2': 4}
# 0.763101601600647,0.04006275224791655 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# 0.7760416666666666

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV 1/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=0.649 total time=   2.4s
# [CV 2/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=0
5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.773 total time=   2.2s
# [CV 4/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.850 total time=   2.2s
# [CV 5/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.778 total time=   2.3s
# [CV 1/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.727 total time=   2.2s
# [CV 2/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.695 total time=   2.2s
# [CV 3/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.766 total time=   2.7s
# [CV 4/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.843 total time=   2.2s
# [CV 5/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2;, score=0.771 total time=   2.2s
# [CV 1/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.721 total time=   2.2s
# [CV 2/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.701 total time=   2.2s
# [CV 3/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.766 total time=   2.2s
# [CV 4/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.837 total time=   2.2s
# [CV 5/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4;, score=0.745 total time=   2.1s
# [CV 1/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.727 total time=   1.9s
# [CV 2/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.701 total time=   1.8s
# [CV 3/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.753 total time=   1.8s
# [CV 4/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.824 total time=   2.2s
# [CV 5/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8;, score=0.758 total time=   1.8s
# [CV 1/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.747 total time=   1.8s
# [CV 2/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.682 total time=   2.0s
# [CV 3/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.779 total time=   2.1s
# [CV 4/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=0.837 total time=   1.8s
# [CV 5/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# ...
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 224/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.584 total time=  10.0s
# [CV 3/5; 224/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 224/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.630 total time=   9.8s
# [CV 4/5; 224/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 224/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.745 total time=  10.2s
# [CV 5/5; 224/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 224/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=4;, score=0.647 total time=   9.9s
# [CV 1/5; 225/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 225/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.649 total time=  10.6s
# [CV 2/5; 225/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 225/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.584 total time=  11.5s
# [CV 3/5; 225/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 225/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.630 total time=  12.9s
# [CV 4/5; 225/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 225/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.745 total time=  11.5s
# [CV 5/5; 225/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 225/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.001, neuron1=16, neuron2=8;, score=0.647 total time=  12.0s
# [CV 1/5; 226/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 226/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.649 total time=  11.6s
# [CV 2/5; 226/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 226/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.584 total time=  11.5s
# [CV 3/5; 226/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 226/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.630 total time=  11.3s
# [CV 4/5; 226/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 226/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.745 total time=  10.9s
# [CV 5/5; 226/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 226/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=2;, score=0.647 total time=  10.7s
# [CV 1/5; 227/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 227/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.649 total time=  11.2s
# [CV 2/5; 227/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 227/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.584 total time=  10.6s
# [CV 3/5; 227/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 227/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.630 total time=  11.0s
# [CV 4/5; 227/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 227/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.745 total time=  10.8s
# [CV 5/5; 227/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 227/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=4;, score=0.647 total time=  10.4s
# [CV 1/5; 228/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 228/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.649 total time=  10.3s
# [CV 2/5; 228/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 228/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.584 total time=  10.1s
# [CV 3/5; 228/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 228/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.630 total time=   9.8s
# [CV 4/5; 228/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 228/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.745 total time=  10.2s
# [CV 5/5; 228/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 228/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=4, neuron2=8;, score=0.647 total time=  11.4s
# [CV 1/5; 229/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 229/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.649 total time=  10.9s
# [CV 2/5; 229/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 229/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.584 total time=  11.0s
# [CV 3/5; 229/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 3/5; 229/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.630 total time=  12.7s
# [CV 4/5; 229/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 4/5; 229/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.745 total time=  11.3s
# [CV 5/5; 229/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 5/5; 229/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=2;, score=0.647 total time=  11.0s
# [CV 1/5; 230/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 1/5; 230/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=4;, score=0.649 total time=  10.8s
# [CV 2/5; 230/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV 2/5; 230/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=4;, score=0.584 total time=  11.6s
# [CV 3/5; 230/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=zero, learning_rate=0.01, neuron1=8, neuron2=4
# C:\Users\Hp\anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
